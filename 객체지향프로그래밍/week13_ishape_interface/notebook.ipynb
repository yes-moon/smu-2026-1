# %% [markdown]
# ### IShape 인터페이스 과제

# %%
# %%writefile src/IShape.java
# // 인터페이스 IShape
# interface IShape {
#     public double getArea();
#     double getPerimeter();
# }
# Out:
# Writing src/IShape.java

# %%
# !javac -d classes/ -sourcepath src/ src/IShape.java

# %%
# %%writefile src/Rectangle.java
# // 클래스 Rectangle: 너비, 높이를 가지고 IShape을 구현
# class Rectangle implements IShape {
#     protected double width;
#     protected double height;
#
#     public Rectangle(double width, double height) {
#         this.width = width;
#         this.height = height;
#     }
#
#     @Override
#     public double getArea() {
#         return width * height;
#     }
#
#     @Override
#     public double getPerimeter() {
#         return 2 * (width + height);
#     }
#
#     @Override
#     public String toString() {
#         return String.format("사각형 - 너비: %.2f, 높이: %.2f, 둘레: %.2f, 너비: %.2f",
#                 width, height, getPerimeter(), getArea());
#     }
# }
# Out:
# Writing src/Rectangle.java

# %%
# !javac -d classes/ -sourcepath src/ src/Rectangle.java

# %%
# %%writefile src/Circle.java
# // 클래스 Circle: 반지름을 가지고 IShape을 구현
# class Circle implements IShape {
#     protected double radius;
#
#     public Circle(double radius) {
#         this.radius = radius;
#     }
#
#     @Override
#     public double getArea() {
#         return Math.PI * radius * radius;
#     }
#
#     @Override
#     public double getPerimeter() {
#         return 2 * Math.PI * radius;
#     }
#
#     @Override
#     public String toString() {
#         return String.format("원 - 반지름: %.2f, 둘레: %.2f, 너비: %.2f",
#                 radius, getPerimeter(), getArea());
#     }
# }
# Out:
# Writing src/Circle.java

# %%
# !javac -d classes/ -sourcepath src/ src/Circle.java

# %%
# %%writefile src/ShapeTest.java
# // 메인 클래스
# class ShapeTest {
#     public static void main(String[] args) {
#         // 원: 반지름 3
#         Circle circle = new Circle(3);
#         // 사각형: 너비 5, 높이 10
#         Rectangle rectangle = new Rectangle(5, 10);
#
#         // toString() 오버라이드 결과 출력
#         System.out.println(circle);
#         System.out.println(rectangle);
#     }
# }
# Out:
# Writing src/ShapeTest.java

# %%
# !javac -d classes/ -sourcepath src/ src/ShapeTest.java

# %%
# !java -cp classes ShapeTest
# Out:
# 원 - 반지름: 3.00, 둘레: 18.85, 너비: 28.27
# 사각형 - 너비: 5.00, 높이: 10.00, 둘레: 30.00, 너비: 50.00
